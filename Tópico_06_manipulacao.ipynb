# %% [markdown]
# # Manipulação de dados
#
# **Objetivo:** usar um arquivo `.dta` real (ESEB 2022) e praticar:
# - Ler o Stata mantendo **rótulos** (labels)
# - `select` (selecionar colunas), `filter` (filtrar casos), `rename` (renomear)
# - Transformar **idade** em faixas (categorias) com `pd.cut`/`pd.qcut`
# - **Recodificar** categorias

# %% [markdown]
# ### Ler o `.dta`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 60)
pd.set_option('display.precision', 1)

# %%
df = pd.read_stata('eseb_22.dta')
# Out:
# /var/folders/j_/tz9gc8yj4q353002z3gl5_500000gn/T/ipykernel_49585/934954646.py:1: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   df = pd.read_stata('eseb_22.dta')

# %%
df.head()
# Out:
#       SbjNum  Nquest Data_ENTREVISTA             MUN              UF      REG  \
# 0  177011603       1      11/19/2022  Rio De Janeiro  Rio De Janeiro  Sudeste
# 1  177011604       2      11/19/2022  Rio De Janeiro  Rio De Janeiro  Sudeste
# 2  177011605       3      11/19/2022  Rio De Janeiro  Rio De Janeiro  Sudeste
# 3  177011606       4      11/19/2022  Rio De Janeiro  Rio De Janeiro  Sudeste
# 4  177011607       5      11/19/2022  Rio De Janeiro  Rio De Janeiro  Sudeste
#
#    T_ZONA T_RESID        D02  T_D01A_1  T_D01A_2  T_D01A_3  D01A_IDADE  \
# 0  Urbano    Casa  Masculino         3        11      1961          61
# 1  Urbano    Casa   Feminino        10         4      1964          58
# 2  Urbano    Casa   Feminino        15         8      1972          50
# 3  Urbano    Casa   Feminino         2         7      1958          64
# 4  Urbano    Casa   Feminino        11         6      1982          40
#
#      D01A_FX_ID                                                D03  \
# 0  55 a 64 anos                      Ensino universitário completo
# 1  55 a 64 anos                      Ensino universitário completo
# 2  45 a 54 Anos       Colegial completo (3ª série do ensino médio)
# 3  55 a 64 anos  Ensino universitário incompleto ou especializa...
# 4  35 a 44 Anos  Ginásio completo (8ª série ou 9º ano do ensino...
#
#                                 D06  \
# 0          Autônomo / conta própria
# 1                      Dona de casa
# 2          Autônomo / conta própria
# 3  Aposentado por tempo de trabalho
# 4                      Dona de casa
#
#                                                 D06a  \
# 0  Trabalha em tempo integral (32 horas ou mais p...
# 1                                                NaN
# 2  Trabalha em meio período (de 15 a 31 horas por...
# 3                                                NaN
# 4                                                NaN
#
#                                                  D08  \
# 0  Proprietário / funcionário / empregado de empr...
# 1                                                NaN
# 2              Autônomo / trabalha por conta própria
# 3                                                NaN
# 4                                                NaN
#
#                                                 D07a                 Q01  \
# 0  SETOR TERCIÁRIO: (transporte, comunicações, co...  Muito interessado,
# 1                                                NaN  Muito interessado,
# 2  SETOR TERCIÁRIO: (transporte, comunicações, co...  Muito interessado,
# 3                                                NaN  Muito interessado,
# 4                                                NaN  Muito interessado,
#
#                 Q02a               Q02b               Q02c               Q02d  \
# 0  Nenhum/ zero dias        Quatro dias  Nenhum/ zero dias  Nenhum/ zero dias
# 1  Nenhum/ zero dias          Sete dias          Sete dias          Sete dias
# 2  Nenhum/ zero dias  Nenhum/ zero dias          Dois dias  Nenhum/ zero dias
# 2          MASCULINO  0.93
# 3          MASCULINO  1.45
# 4          MASCULINO  0.62
#
# [5 rows x 177 columns]

# %%
print(df.columns.tolist())
# Out:
# ['SbjNum', 'Nquest', 'Data_ENTREVISTA', 'MUN', 'UF', 'REG', 'T_ZONA', 'T_RESID', 'D02', 'T_D01A_1', 'T_D01A_2', 'T_D01A_3', 'D01A_IDADE', 'D01A_FX_ID', 'D03', 'D06', 'D06a', 'D08', 'D07a', 'Q01', 'Q02a', 'Q02b', 'Q02c', 'Q02d', 'Q02e', 'Q02f', 'Q02g', 'Q03', 'Q04a', 'Q04b', 'Q04c', 'Q04d', 'Q05a', 'Q05b', 'Q05c', 'Q06', 'Q07a', 'Q07b', 'Q07c', 'Q07d', 'Q07e', 'Q07f', 'Q07g', 'Q07h', 'Q07i', 'Q07j', 'Q07l', 'Q07m', 'Q07n', 'Q07o', 'Q08', 'Q08b', 'Q09', 'Q10P1a', 'Q10P1b', 'Q10P2a', 'Q10P2b', 'Q10G1', 'Q10G2', 'Q10CD', 'Q10AL', 'Q10AL_DF', 'Q10S', 'Q11a', 'Q11b', 'Q11c', 'Q12', 'Q13', 'Q14A', 'Q14A2', 'Q14B', 'Q14B_agregada', 'Q14B2', 'Q14B2_agregada', 'Q14G1', 'Q14G1_agregada', 'Q14G2', 'Q14G2_agregada', 'Q14S1', 'Q14S1_agregada', 'Q14S2', 'Q14S2_agregada', 'Q14CD', 'Q14CD_agregada', 'Q14AL', 'Q14AL_agregada', 'Q14AL_DF', 'Q15', 'Q16_1', 'Q16_2', 'Q16_3', 'Q16_4', 'Q16_5', 'Q16_6', 'Q16_7', 'Q16_8', 'Q16_9', 'Q16_10', 'Q16_11', 'Q16_12', 'Q16_13', 'Q17_1', 'Q17_2', 'Q17_3', 'Q17_4', 'Q17_5', 'Q17_6', 'Q17_7', 'Q17_8', 'Q17_9', 'Q17_10', 'Q17_11', 'Q17_12', 'Q17_13', 'Q18_1', 'Q18_2', 'Q18_3', 'Q18_4', 'Q18_5', 'Q18_6', 'Q18_7', 'Q18_8', 'Q18_9', 'Q18_10', 'Q18_11', 'Q18_12', 'Q18_13', 'Q19', 'Q22', 'Q23a', 'Q23b', 'Q23c', 'Q23d', 'Q24', 'Q25a', 'Q25b', 'Q26a', 'Q26b', 'Q27a', 'Q27b', 'Q27c', 'Q27d', 'Q28_codigos_desagregados', 'Q28_codigos_agregados1', 'Q29', 'Q30a', 'Q30b', 'Q30c', 'Q31_1', 'Q31_2', 'Q31_3', 'Q31_4', 'Q31_5', 'Q31_6', 'Q31_7', 'Q31_8', 'Q31_9', 'Q31_10', 'Q31_11', 'Q31_12', 'Q31_13', 'Q31_14', 'Q32', 'D04', 'D05', 'D09_RENDAF', 'D09a_FX_RENDAF', 'D09a_RENDAF', 'D11', 'D10', 'D10a', 'D12_COR', 'D12a', 'D20', 'ID_entrevistador', 'sexo_entrevistador', 'peso']

# %% [markdown]
# ### Selecionar algumas variveis para trabalhar

# %%
df1 = df[['D02', 'D03', 'D01A_IDADE', 'REG', 'Q10P2b']]

df1.head()
# Out:
#          D02                                                D03  D01A_IDADE  \
# 0  Masculino                      Ensino universitário completo          61
# 1   Feminino                      Ensino universitário completo          58
# 2   Feminino       Colegial completo (3ª série do ensino médio)          50
# 3   Feminino  Ensino universitário incompleto ou especializa...          64
# 4   Feminino  Ginásio completo (8ª série ou 9º ano do ensino...          40
#
#        REG          Q10P2b
# 0  Sudeste            Lula
# 1  Sudeste            Lula
# 2  Sudeste  Jair Bolsonaro
# 3  Sudeste  Jair Bolsonaro
# 4  Sudeste             NaN

# %% [markdown]
# ### Renomear variaveis

# %% [raw]
# # Método mais comum e legível
#
# df = df.rename(columns={
#     'nome_antigo_1': 'nome_novo_1',
#     'nome_antigo_2': 'nome_novo_2',
#     'nome_antigo_3': 'nome_novo_3',
#     'nome_antigo_4': 'nome_novo_4',
#     'nome_antigo_5': 'nome_novo_5'
# })

# %%
df1= df1.rename(columns={
    'D02': 'sexo',
    'D03': 'ensino', 
    'D01A_IDADE': 'idade',
    'REG': 'regiao',
    'Q10P2b': 'voto2'
})

df1.head()
# Out:
#         sexo                                             ensino  idade  \
# 0  Masculino                      Ensino universitário completo     61
# 1   Feminino                      Ensino universitário completo     58
# 2   Feminino       Colegial completo (3ª série do ensino médio)     50
# 3   Feminino  Ensino universitário incompleto ou especializa...     64
# 4   Feminino  Ginásio completo (8ª série ou 9º ano do ensino...     40
#
#     regiao           voto2
# 0  Sudeste            Lula
# 1  Sudeste            Lula
# 2  Sudeste  Jair Bolsonaro
# 3  Sudeste  Jair Bolsonaro
# 4  Sudeste             NaN

# %% [markdown]
# ### Categorizar idade

# %%
df1['faixa_idade4'] = pd.cut(df1['idade'], 
                            bins=[16,30,45,60,110], 
                            labels=['16-29', '30-44', '45-59', '60+'])

# Usando apenas 3 categorias
df1['faixa_idade3'] = pd.cut(df1['idade'], 
                                   bins=[18,35,55,100], 
                                   labels=['Jovem','Adulto','Senior'])

# %%
df1.head()
# Out:
#         sexo                                             ensino  idade  \
# 0  Masculino                      Ensino universitário completo     61
# 1   Feminino                      Ensino universitário completo     58
# 2   Feminino       Colegial completo (3ª série do ensino médio)     50
# 3   Feminino  Ensino universitário incompleto ou especializa...     64
# 4   Feminino  Ginásio completo (8ª série ou 9º ano do ensino...     40
#
#     regiao           voto2 faixa_idade4 faixa_idade3
# 0  Sudeste            Lula          60+       Senior
# 1  Sudeste            Lula        45-59       Senior
# 2  Sudeste  Jair Bolsonaro        45-59       Adulto
# 3  Sudeste  Jair Bolsonaro          60+       Senior
# 4  Sudeste             NaN        30-44       Adulto

# %% [markdown]
# ### Observar as categorias de cada variavel

# %%
df1['faixa_idade4'].value_counts()
# Out:
# faixa_idade4
# 30-44    641
# 16-29    560
# 45-59    497
# 60+      297
# Name: count, dtype: int64

# %%
df1['sexo'].value_counts(normalize=True)
# Out:
# sexo
# Feminino     0.51
# Masculino    0.49
# Name: proportion, dtype: float64

# %%
df1['ensino'].value_counts()
# Out:
# ensino
# Colegial completo (3ª série do ensino médio)                                     711
# Ensino universitário completo                                                    240
# Colegial incompleto (até 2ª série do ensino médio)                               187
# Ensino universitário incompleto ou especialização (técnico após ensino médio)    181
# Ginásio completo (8ª série ou 9º ano do ensino fundamental)                      166
# Primário completo (4ª.série ou 5º ano do ensino fundamental)                     163
# Ginásio incompleto (até 7ª série ou 8º ano do ensino fundamental)                146
# Primário incompleto (até 3ª série ou 4º ano do ensino fundamental)               128
# Pós-graduação ou mais                                                             43
# Analfabeto/ nunca frequentou escola                                               35
# NÃO RESPONDEU                                                                      1
# Name: count, dtype: int64

# %% [markdown]
# ### Recodificar Variáveis categoricas

# %%
recode_educacao = {
    'Analfabeto/ nunca frequentou escola': 'Fundamental',
    'Primário incompleto (até 3ª série ou 4º ano do ensino fundamental)': 'Fundamental',
    'Primário completo (4ª.série ou 5º ano do ensino fundamental)': 'Fundamental',
    'Ginásio incompleto (até 7ª série ou 8º ano do ensino fundamental)': 'Fundamental',
    'Ginásio completo (8ª série ou 9º ano do ensino fundamental)': 'Fundamental',
    'Colegial incompleto (até 2ª série do ensino médio)': 'Médio',
    'Colegial completo (3ª série do ensino médio)': 'Médio',
    'Ensino universitário incompleto ou especialização (técnico após ensino médio)': 'Superior',
    'Ensino universitário completo': 'Superior',
    'Pós-graduação ou mais': 'Superior'
}

# Aplicando o recode
df1['ensino_cat'] = df1['ensino'].map(recode_educacao)

# Verificando o resultado
df1['ensino_cat'].value_counts()
# Out:
# ensino_cat
# Médio          898
# Fundamental    638
# Superior       464
# Name: count, dtype: int64

# %%
df1.head()
# Out:
#         sexo                                             ensino  idade  \
# 0  Masculino                      Ensino universitário completo     61
# 1   Feminino                      Ensino universitário completo     58
# 2   Feminino       Colegial completo (3ª série do ensino médio)     50
# 3   Feminino  Ensino universitário incompleto ou especializa...     64
# 4   Feminino  Ginásio completo (8ª série ou 9º ano do ensino...     40
#
#     regiao           voto2 faixa_idade4 faixa_idade3   ensino_cat
# 0  Sudeste            Lula          60+       Senior     Superior
# 1  Sudeste            Lula        45-59       Senior     Superior
# 2  Sudeste  Jair Bolsonaro        45-59       Adulto        Médio
# 3  Sudeste  Jair Bolsonaro          60+       Senior     Superior
# 4  Sudeste             NaN        30-44       Adulto  Fundamental

# %% [markdown]
# ### A função: Agrupar

# %% [markdown]
# ### O que é groupby?
#
# Quando você tem um banco de dados, muitas vezes quer agrupar observações por uma categoria e calcular resumos (média, soma, contagem etc.).
# No pandas, usamos df.groupby(...) para isso.

# %%
df1.groupby("sexo")["idade"].mean()
# Out:
# /var/folders/j_/tz9gc8yj4q353002z3gl5_500000gn/T/ipykernel_49585/988668940.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df1.groupby("sexo")["idade"].mean()
# sexo
# Masculino    42.08
# Feminino     42.37
# Name: idade, dtype: float64

# %%
df1.groupby("ensino_cat")["idade"].median()
# Out:
# ensino_cat
# Fundamental    52.0
# Médio          36.0
# Superior       35.0
# Name: idade, dtype: float64

# %%
df1.groupby("sexo")["idade"].agg(["mean", "min", "max"])
# Out:
# /var/folders/j_/tz9gc8yj4q353002z3gl5_500000gn/T/ipykernel_49585/3327228856.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df1.groupby("sexo")["idade"].agg(["mean", "min", "max"])
#             mean  min  max
# sexo
# Masculino  42.08   16   88
# Feminino   42.37   16   90

# %% [markdown]
# ### Resetando o índice
#
# Por padrão, groupby devolve um índice especial.
# Se quiser um DataFrame “plano” de novo, use .reset_index():

# %%
df1.groupby("ensino_cat")["idade"].mean().reset_index()
# Out:
#     ensino_cat  idade
# 0  Fundamental   51.1
# 1        Médio   37.9
# 2     Superior   38.5
